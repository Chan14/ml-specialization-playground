# %%
import numpy as np
import matplotlib.pyplot as plt
# plt.style.use('./deeplearning.mplstyle')
import tensorflow as tf
import keras
from keras.activations import linear, relu, sigmoid
# %matplotlib widget
import warnings
warnings.simplefilter(action='ignore', category=UserWarning)
# Out:
# 2026-01-08 23:54:46.417344: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def widget_vis(fig):
    fig.canvas.toolbar_visible = False
    fig.canvas.header_visible = False
    fig.canvas.footer_visible = False

# %%
def plt_act_trio():
    X = np.linspace(-5, 5, 100)
    fig, ax = plt.subplots(1, 3, figsize=(6, 2))
    widget_vis(fig)
    ax[0].plot(X, linear(X))
    ax[0].set_title("Linear")
    ax[1].plot(X, sigmoid(X))
    ax[1].set_title("Sigmoid")
    ax[2].plot(X, relu(X))
    ax[2].set_title("ReLu")
    for a in ax:
        a.axvline(x=0, lw=0.3, c="black")
        a.axhline(y=0, lw=0.3, c="black")
    fig.suptitle("Common Activation Functions", fontsize=14)
    fig.tight_layout(pad=0.2)
    plt.show()

# %%
plt_act_trio()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …
